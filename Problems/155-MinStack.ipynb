# %%
class MinStack(object):

    def __init__(self):
        self.stack=[]
        self.size=0
        self.minVal={0:sys.maxsize}

    def push(self, val):
        """
        :type val: int
        :rtype: None
        """
        self.stack.append(val)
        self.size+=1
        self.minVal[self.size]=min(val,self.minVal[self.size-1])
        

    def pop(self):
        """
        :rtype: None
        """
        self.stack.pop(self.size-1)
        self.size-=1
        

    def top(self):
        """
        :rtype: int
        """
        return self.stack[self.size-1]
        

    def getMin(self):
        """
        :rtype: int
        """
        return self.minVal[self.size]
        


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()

# %%
  
class MinStack(object):

    def __init__(self):
        self.stack = []

    def push(self, x):
        """
        :type val: int
        :rtype: None
        """
        if not self.stack:
            self.stack.append((x, x))
            return

        current_min = self.stack[-1][1]
        self.stack.append((x, min(x, current_min)))
        

    def pop(self):
        """
        :rtype: None
        """
        self.stack.pop()
        

    def top(self):
        """
        :rtype: int
        """
        return self.stack[-1][0]
        

    def getMin(self):
        """
        :rtype: int
        """
        return self.stack[-1][1]


# Your MinStack object will be instantiated and called as such:
# obj = MinStack()
# obj.push(val)
# obj.pop()
# param_3 = obj.top()
# param_4 = obj.getMin()
